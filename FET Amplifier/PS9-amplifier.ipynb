# %%
import numpy as np
import matplotlib.pyplot as plt

# Custom settings
plt.style.use('classic')
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.linewidth'] = 1.2
plt.rcParams['savefig.facecolor'] = 'white'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['figure.dpi'] = 100

# %%
data = np.loadtxt('Data-20260705/20260507-0001.csv', delimiter=',', skiprows=1)
time = data[:, 0]
V_in = data[:, 1]
V_out = data[:, 2]

window_size = 5
window = np.ones(window_size) / window_size

V_in_smooth = np.convolve(V_in, window, mode='same')
V_out_smooth = np.convolve(V_out, window, mode='same')

plt.plot(time, -V_in_smooth, label='Input Voltage', color='blue', lw=1.5)
plt.plot(time, 0.1+V_out_smooth/1000*41, label='Output Voltage', color='red', lw=1.5)
plt.xlabel('Time (ms)', fontsize=12)
plt.ylabel('Voltage (V)', fontsize=12)
plt.xlim(-10, 10)
plt.ylim(-2, 2)
plt.title('PS9 Amplifier Response', fontsize=14)
plt.legend()
plt.show()

# %%
data = np.loadtxt('./Data-20260705/20260507-0002.csv', delimiter=',', skiprows=1)
time = data[:, 0]
V_in = data[:, 1]
V_out = data[:, 2]

window_size = 5
window = np.ones(window_size) / window_size

V_in_smooth = np.convolve(V_in, window, mode='same')
V_out_smooth = np.convolve(V_out, window, mode='same')

plt.plot(time, -V_in_smooth, label='Input Voltage', color='blue', lw=1.5)
plt.plot(time, 0.1+V_out_smooth/1000*41, label='Output Voltage', color='red', lw=1.5)
plt.xlabel('Time (ms)', fontsize=12)
plt.ylabel('Voltage (V)', fontsize=12)
plt.xlim(-10, 10)
plt.ylim(-2, 2)
plt.title('PS9 Amplifier Response', fontsize=14)
plt.legend()
plt.show()

# %%
data = np.loadtxt('Data-20260805/20260508-0001.csv', delimiter=',', skiprows=1)
time = data[:, 0]
V_in = data[:, 1]
V_out = data[:, 2]

window_size = 5
window = np.ones(window_size) / window_size

V_in_smooth = np.convolve(V_in, window, mode='same')
V_out_smooth = np.convolve(V_out, window, mode='same')

plt.plot(time, -V_in_smooth, label='Input Voltage', color='blue', lw=1.5)
plt.plot(time, 0.3+2*V_out_smooth, label='Output Voltage', color='red', lw=1.5)
plt.xlabel('Time (us)', fontsize=14)
plt.ylabel('Voltage (V)', fontsize=14)
plt.xlim(-300, 300)
plt.ylim(-2, 2)
plt.title(r'PS9 Amplifier Response ($V_\text{DD} = -30$ V, $R_D = 50$ M$\Omega$)', fontsize=15)
plt.legend(fontsize=15)
# plt.savefig("amplifier-PS9-response-sin.eps", format='eps', bbox_inches='tight')
plt.show()

# %%
data = np.loadtxt('Data-20260805/20260508-0002.csv', delimiter=',', skiprows=1)
time = data[:, 0]
V_in = data[:, 1]
V_out = data[:, 2]

window_size = 5
window = np.ones(window_size) / window_size

V_in_smooth = np.convolve(V_in, window, mode='same')
V_out_smooth = np.convolve(V_out, window, mode='same')

plt.plot(time, -V_in_smooth, label='Input Voltage', color='blue', lw=1.5)
plt.plot(time, 0.3+2*V_out_smooth, label='Output Voltage', color='red', lw=1.5)
plt.xlabel('Time (us)', fontsize=14)
plt.ylabel('Voltage (V)', fontsize=14)
plt.xlim(-300, 300)
plt.ylim(-2, 2)
plt.title(r'PS9 Amplifier Response ($V_\text{DD} = -30$ V, $R_D = 50$ M$\Omega$)', fontsize=15)
plt.legend(fontsize=15)
# plt.savefig("amplifier-PS9-response-square.eps", format='eps', bbox_inches='tight')
plt.show()

# %%
data = np.loadtxt('Data-20260805/20260508-0003.csv', delimiter=',', skiprows=1)
time = data[:, 0]
V_in = data[:, 1]
V_out = data[:, 2]

window_size = 5
window = np.ones(window_size) / window_size

V_in_smooth = np.convolve(V_in, window, mode='same')
V_out_smooth = np.convolve(V_out, window, mode='same')

plt.plot(time, -V_in_smooth, label='Input Voltage', color='blue', lw=1.5)
plt.plot(time, V_out_smooth, label='Output Voltage', color='red', lw=1.5)
plt.xlabel('Time (us)', fontsize=12)
plt.ylabel('Voltage (V)', fontsize=12)
plt.xlim(-500, 500)
plt.ylim(-2, 2)
plt.title('PS9 Amplifier Response', fontsize=14)
plt.legend()
plt.show()

# %%
data = np.loadtxt('Data-20260805/20260508-0004.csv', delimiter=',', skiprows=1)
time = data[:, 0]
V_in = data[:, 1]
V_out = data[:, 2]

window_size = 5
window = np.ones(window_size) / window_size

V_in_smooth = np.convolve(V_in, window, mode='same')
V_out_smooth = np.convolve(V_out, window, mode='same')

plt.plot(time, -V_in_smooth, label='Input Voltage', color='blue', lw=1.5)
plt.plot(time, V_out_smooth, label='Output Voltage', color='red', lw=1.5)
plt.xlabel('Time (us)', fontsize=12)
plt.ylabel('Voltage (V)', fontsize=12)
plt.xlim(-500, 500)
plt.ylim(-2, 2)
plt.title('PS9 Amplifier Response', fontsize=14)
plt.legend()
plt.show()
