# %%
import numpy as np
import matplotlib.pyplot as plt

# Custom settings
plt.style.use('classic')
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.linewidth'] = 1.2
plt.rcParams['savefig.facecolor'] = 'white'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['figure.dpi'] = 100

# %%
data = np.loadtxt('Data-20260605/20260506-0001.csv', delimiter=',', skiprows=1)
time = data[:, 0]
V_in = data[:, 1]
V_out = data[:, 2]

window_size = 5
window = np.ones(window_size) / window_size

V_in_smooth = np.convolve(V_in, window, mode='same')
V_out_smooth = np.convolve(V_out, window, mode='same')

plt.plot(time, V_in_smooth, label='Gate Voltage', color='blue', lw=1.5)
plt.plot(time, V_out_smooth, label='Output Voltage', color='red', lw=1.5)
plt.xlabel('Time (ms)', fontsize=12)
plt.ylabel('Voltage (V)', fontsize=12)
plt.xlim(100, 450)
plt.ylim(-10, 30)
plt.title('FET Amplifier Response', fontsize=14)
plt.legend()
plt.show()
